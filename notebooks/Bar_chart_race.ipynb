# %% [markdown]
# # Bar chart race

# %%
import pandas as pd
import matplotlib.pyplot
import matplotlib.dates

from datetime import datetime

df = pd.read_csv("../Materials/KVO_META.csv", encoding='latin-1', index_col=False)

# %%
#De Datum kolom wordt omgezet naar dtype datetime.

df['Date'] = df['Date'].str.strip()
#df['Date'] = pd.to_datetime(df['Date'], format="%d/%m/%Y")

#blanco pagina's worden verwijderd

old_len = len(df)
df = df.dropna(subset=['Production','Date'])
print(f'{old_len - len(df)} of {old_len} records removed')
# Out:
# 0 of 4441 records removed

# %%
import bar_chart_race as bcr
import numpy as np

#test = pd.pivot_table(df, index= ['Collectie'], columns= ['Oorspronkelijke taal'], aggfunc=np.sum )
test = pd.pivot_table(df, index= ['Season'], values = ['Production'], columns = ['Original language'], aggfunc='count')

# %%
def bar_chart_maker (column, n_bars = 3, period_length = 2000):
    
    output = pd.pivot_table(df, index= ['Season'], values = ['Production'], columns = [column], aggfunc='count')
    bar_chart = bcr.bar_chart_race(df=output, filename=None, period_length=period_length, title=str(column), n_bars=3, fixed_max=True, filter_column_colors = True)
    return bar_chart

# %%
bar_chart_maker('Composer');
# Out:
# c:\Users\monaa\anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:284: UserWarning: Glyph 127 () missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# c:\Users\monaa\anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:284: UserWarning: Glyph 128 (\x80) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# c:\Users\monaa\anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:284: UserWarning: Glyph 129 (\x81) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# c:\Users\monaa\anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:284: UserWarning: Glyph 130 (\x82) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# c:\Users\monaa\anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:284: UserWarning: Glyph 131 (\x83) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# ...

# %%
bar_chart_maker('Original language', n_bars = any, period_length=2000);
# Out:
# c:\Users\monaa\anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# c:\Users\monaa\anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))

# %%
output = pd.pivot_table(df, index= ['Season'], values = ['Production'], columns = ['Original language'], aggfunc='count')
bar_chart = bcr.bar_chart_race(df=output, filename=None, period_length=2500, title=str(['Original language']), n_bars=3, fixed_max=True, filter_column_colors = True)
# Out:
# c:\Users\monaa\anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# c:\Users\monaa\anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))

# %%
bar_chart
# Out:
# <video width="992" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...
